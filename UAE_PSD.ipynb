# %%
#plot UAE background PSD in dry day (no cloud) & sub cloud region

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import xarray as xr
import itertools
from os import path
import math
import glob

# %%
dirpath='/glade/u/home/sisichen/work_dir/projects_results/UAE_new_material/'
dry_psd_file='dry_psd_SF5.dat'
subcloud_psd_file='subcloud_psd_SF4.dat'
dry_psd_path=dirpath+dry_psd_file
subcloud_psd_path=dirpath+subcloud_psd_file

subcloud_psd = pd.read_csv(subcloud_psd_path,sep='\s+',header=None,names=['D','N'])
dry_psd      = pd.read_csv(dry_psd_path,sep='\s+',header=None,names=['D','N'])

# %%
dry_psd.D.size
# Out:
# 60

# %%
for i in size()
dry_psd
